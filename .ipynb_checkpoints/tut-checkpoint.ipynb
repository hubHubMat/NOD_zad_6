# %% [markdown]
# # Ćwiczenie laboratoryjne: Analiza danych z wykorzystaniem narzędzi do modelowania regresji

# %% [markdown]
# ## Modelowanie regresji w Pythonie

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

data = load_iris()
X, y = data.data, data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
print("R^2:", r2_score(y_test, y_pred_lr))
# Out:
# R^2: 0.5055963826961418

# %% [markdown]
# ## Wpływ zmiennych objaśniających na predykcję

# %%
from sklearn.linear_model import Ridge
from sklearn.datasets import load_diabetes

# Załaduj dane
data = load_diabetes()
X, y = data.data, data.target

# Trenuj model Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(X, y)

# Współczynniki regresji jako miara ważności cech
feature_importance = abs(ridge.coef_)
print("Ważność cech:", feature_importance)
# Out:
# Ważność cech: [ 29.46611189  83.15427636 306.35268015 201.62773437   5.90961437
#   29.51549508 152.04028006 117.3117316  262.94429001 111.87895644]

# %% [markdown]
# ## Analiza reszt

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import numpy as np

# Oblicz reszty
residuals = y - ridge.predict(X)

# Histogram reszt
plt.hist(residuals, bins=20)
plt.title("Histogram reszt")
plt.show()

# Test Shapiro-Wilka
stat, p = shapiro(residuals)
print("Statystyka Shapiro-Wilka:", stat, "P-wartość:", p)
# Out:
# Statystyka Shapiro-Wilka: 0.982184886932373 P-wartość: 2.9706814530072734e-05

# %% [markdown]
# ## Autokorelacja reszt

# %%
from statsmodels.stats.stattools import durbin_watson

# Test Durbin-Watsona
dw_stat = durbin_watson(residuals)
print("Statystyka Durbin-Watsona:", dw_stat)
# Out:
# Statystyka Durbin-Watsona: 1.9276168836842196

# %% [markdown]
# # Regresja za pomocą sieci neuronowych

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Tworzenie sztucznego zbioru danych regresji
X, y = make_regression(n_samples=1000, n_features=10, noise=0.1)
y = y.reshape(-1, 1)

# Normalizacja danych
scaler_X = StandardScaler()
scaler_y = StandardScaler()
X = scaler_X.fit_transform(X)
y = scaler_y.fit_transform(y)

# Podział na zbiory treningowy i testowy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Budowa sieci neuronowej
model = Sequential([
    Dense(64, activation='relu', input_shape=(X.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # Warstwa wyjściowa dla regresji
])

# Kompilacja modelu
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Trenowanie modelu
history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32)

# Ocena modelu
loss, mae = model.evaluate(X_test, y_test)
print("Średni błąd absolutny (MAE):", mae)

# Przewidywanie
y_pred = scaler_y.inverse_transform(model.predict(X_test))
# Out:
# Epoch 1/100
# 20/20 [==============================] - 2s 22ms/step - loss: 0.5366 - mae: 0.5794 - val_loss: 0.2650 - val_mae: 0.4007
# Epoch 2/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1358 - mae: 0.2773 - val_loss: 0.0530 - val_mae: 0.1753
# Epoch 3/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0398 - mae: 0.1588 - val_loss: 0.0358 - val_mae: 0.1529
# Epoch 4/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0276 - mae: 0.1317 - val_loss: 0.0264 - val_mae: 0.1284
# Epoch 5/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0193 - mae: 0.1092 - val_loss: 0.0217 - val_mae: 0.1165
# Epoch 6/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0147 - mae: 0.0961 - val_loss: 0.0175 - val_mae: 0.1065
# Epoch 7/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0861 - val_loss: 0.0150 - val_mae: 0.0986
# Epoch 8/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0791 - val_loss: 0.0136 - val_mae: 0.0936
# Epoch 9/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0084 - mae: 0.0727 - val_loss: 0.0125 - val_mae: 0.0915
# Epoch 10/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0075 - mae: 0.0684 - val_loss: 0.0118 - val_mae: 0.0887
# Epoch 11/100
# 20/20 [==============================] - 0s 9ms/step - loss: 0.
# Epoch 82/100
# 20/20 [==============================] - 0s 13ms/step - loss: 3.8820e-04 - mae: 0.0152 - val_loss: 0.0058 - val_mae: 0.0574
# Epoch 83/100
# 20/20 [==============================] - 0s 6ms/step - loss: 3.7166e-04 - mae: 0.0148 - val_loss: 0.0058 - val_mae: 0.0573
# Epoch 84/100
# 20/20 [==============================] - 0s 8ms/step - loss: 3.5782e-04 - mae: 0.0144 - val_loss: 0.0059 - val_mae: 0.0570
# Epoch 85/100
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4454e-04 - mae: 0.0142 - val_loss: 0.0058 - val_mae: 0.0566
# Epoch 86/100
# 20/20 [==============================] - 0s 9ms/step - loss: 3.4566e-04 - mae: 0.0143 - val_loss: 0.0058 - val_mae: 0.0563
# Epoch 87/100
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2479e-04 - mae: 0.0140 - val_loss: 0.0056 - val_mae: 0.0562
# Epoch 88/100
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1598e-04 - mae: 0.0138 - val_loss: 0.0057 - val_mae: 0.0565
# Epoch 89/100
# 20/20 [==============================] - 0s 8ms/step - loss: 3.3890e-04 - mae: 0.0142 - val_loss: 0.0057 - val_mae: 0.0564
# Epoch 90/100
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9141e-04 - mae: 0.0132 - val_loss: 0.0057 - val_mae: 0.0560
# Epoch 91/100
# 20/20 [==============================] - 0s 10ms/step - loss: 2.8545e-04 - mae: 0.0128 - val_loss: 0.0055 - val_mae: 0.0551
# Epoch 92/100
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9682e-04 - mae: 0.0133 - val_loss: 0.0055 - val_mae: 0.0555
# Epoch 93/100
# 20/20 [==============================] - 0s 10ms/step - loss: 2.7398e-04 - mae: 0.0128 - val_loss: 0.0056 - val_mae: 0.0560
# Epoch 94/100
# 20/20 [==============================] - 0s 11ms/step - loss: 2.6397e-04 - mae: 0.0124 - val_loss: 0.0056 - val_mae: 0.0565
# Epoch 95/100
# 20/20 [==============================] - 0s 6ms/step - loss: 2.5074e-04 - mae: 0.0121 - val_loss: 0.0055 - val_mae: 0.0556
# Epoch 96/100
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5965e-04 - mae: 0.0125 - val_loss: 0.0056 - val_mae: 0.0560
# Epoch 97/100
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5761e-04 - mae: 0.0122 - val_loss: 0.0055 - val_mae: 0.0554
# Epoch 98/100
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5233e-04 - mae: 0.0123 - val_loss: 0.0055 - val_mae: 0.0556
# Epoch 99/100
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3479e-04 - mae: 0.0118 - val_loss: 0.0054 - val_mae: 0.0547
# Epoch 100/100
# 20/20 [==============================] - 0s 6ms/step - loss: 2.2747e-04 - mae: 0.0116 - val_loss: 0.0055 - val_mae: 0.0552
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0043 - mae: 0.0517
# Średni błąd absolutny (MAE): 0.051741741597652435
# 7/7 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Kod Python do wizualizacji sieci neuronowej:

# %%
#! pip install pydot

# %%
#! pip install graphviz

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# Tworzenie przykładowej sieci neuronowej
model = Sequential([
    Dense(64, activation='relu', input_shape=(10,), name='hidden_layer_1'),
    Dense(32, activation='relu', name='hidden_layer_2'),
    Dense(1, name='output_layer')  # Warstwa wyjściowa do regresji
])

# Kompilacja modelu
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Wyświetlenie podsumowania modelu
print("Podsumowanie modelu:")
model.summary()

# Wizualizacja modelu za pomocą plot_model
plot_file = "model_architecture.png"
plot_model(model, to_file=plot_file, show_shapes=True, show_layer_names=True)

# Wyświetlanie zapisanego obrazu
img = plt.imread(plot_file)
plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.axis('off')
plt.title("Architektura sieci neuronowej")
plt.show()
# Out:
# Podsumowanie modelu:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer_1 (Dense)      (None, 64)                704
#
#  hidden_layer_2 (Dense)      (None, 32)                2080
#
#  output_layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 2817 (11.00 KB)
# Trainable params: 2817 (11.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
